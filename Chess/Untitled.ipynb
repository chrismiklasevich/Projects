# %%
#PROJECT OBJECTIVE
#To see if there is a difference between the winning percentages between different openings
#This could be a regression analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sci
import numpy as np

# %%
#Reading in data
data = pd.read_csv("games.csv")

# %%
#Make dataframe from chess data
df =pd.DataFrame(data)

# %%
#Checking some of the variables; how many categorical variables, numerical?
df.dtypes
#df.info
#20058 games
# Out:
# id                 object
# rated                bool
# created_at        float64
# last_move_at      float64
# turns               int64
# victory_status     object
# winner             object
# increment_code     object
# white_id           object
# white_rating        int64
# black_id           object
# black_rating        int64
# moves              object
# opening_eco        object
# opening_name       object
# opening_ply         int64
# dtype: object

# %%
df.loc[:,'created_at'].mean(), df.loc[:,'last_move_at'].mean()
#The last move column is bugged. The chessgames shou;d be finished around by move 80 or at the maximum 100.
#Having a value that is over a million means that there is an error in the column. This is also true
# for the created_at variable.
#Therefore, we are not using that columns

#Removed the column from dataframe
df = df.drop('last_move_at',axis=1)
df = df.drop('created_at',axis=1)
df
# Out:
#              id  rated  turns victory_status winner increment_code  \
# 0      TZJHLljE  False     13      outoftime  white           15+2
# 1      l1NXvwaE   True     16         resign  black           5+10
# 2      mIICvQHh   True     61           mate  white           5+10
# 3      kWKvrqYL   True     61           mate  white           20+0
# 4      9tXo1AUZ   True     95           mate  white           30+3
# ...         ...    ...    ...            ...    ...            ...
# 20053  EfqH7VVH   True     24         resign  white          10+10
# 20054  WSJDhbPl   True     82           mate  black           10+0
# 20055  yrAas0Kj   True     35           mate  white           10+0
# 20056  b0v4tRyF   True    109         resign  white           10+0
# 20057  N8G2JHGG   True     78           mate  black           10+0
#
#             white_id  white_rating            black_id  black_rating  \
# 0           bourgris          1500                a-00          1191
# ...

# %%
df.loc[:,'white_rating'].mean(), df.loc[:,'white_rating'].std(),
#df.loc[:,'white_rating'].plot()
# Out:
# (1596.6318675840064, 291.25337573701944)

# %%
df.loc[:,'black_rating'].mean(), df.loc[:,'black_rating'].std()
#df.loc[:,'black_rating'].plot(),
# Out:
# (1588.8319872370128, 291.03612596033696)
